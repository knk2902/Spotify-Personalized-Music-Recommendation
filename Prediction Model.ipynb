# %%
import json
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
like_songs = pd.read_csv("playlist_0.csv",index_col=[0])

like_songs.head()
# Out:
#                        id                     title  danceability  energy  \
# 0  6gBFPUFcJLzWGx4lenP6h2                goosebumps         0.841   0.728
# 1  0nrRP2bk19rLc0orkWPQk2                Wake Me Up         0.532   0.783
# 2  6RUKPb4LETWmmr3iAEQktW  Something Just Like This         0.617   0.635
# 3  7BKLCZ1jbUBVqRi2FVlTVw                    Closer         0.748   0.524
# 4  698ItKASDavgwZ3WjaWjtz                     Faded         0.468   0.627
#
#    key  loudness  mode  acousticness  instrumentalness  liveness  valence  \
# 0    7    -3.370     1        0.0847          0.000000     0.149    0.430
# 1    2    -5.697     1        0.0038          0.001200     0.161    0.643
# 2   11    -6.769     0        0.0498          0.000014     0.164    0.446
# 3    8    -5.599     1        0.4140          0.000000     0.111    0.661
# 4    6    -5.085     1        0.0281          0.000008     0.110    0.159
#
#      tempo  duration_ms  time_signature  num_bars  num_sections  num_segments
# 0  130.049       243837               4       130            11           958
# 1  124.080       247427               4       125            12           948
# 2  103.019       247160               4       105            11           888
# 3   95.010       244960               4        94            11           810
# 4  179.642       212107               4       154             9           687

# %%
dislike_songs = pd.read_csv("playlist_1.csv",index_col=[0])

dislike_songs.head()
# Out:
#                        id              title  danceability  energy  key  \
# 0  6Qn5zhYkTa37e91HC1D7lb  Whatever It Takes         0.672   0.655   10
# 1  1zB4vmk8tFRmM9UULNzbLB            Thunder         0.605   0.822    0
# 2  7qiZfU4dY1lWllzX7mPBI3       Shape of You         0.825   0.652    1
# 3  2tpWsVSb9UEmDRxAl1zhX1     Counting Stars         0.664   0.705    1
# 4  5qaEfEh1AtSdrdrByCP7qR             Demons         0.505   0.710    3
#
#    loudness  mode  acousticness  instrumentalness  liveness  valence    tempo  \
# 0    -5.021     0       0.03620           0.00000    0.1170    0.556  134.945
# 1    -4.833     1       0.00671           0.13400    0.1470    0.288  167.997
# 2    -3.183     0       0.58100           0.00000    0.0931    0.931   95.977
# 3    -4.972     0       0.06540           0.00000    0.1180    0.477  122.016
# 4    -3.015     1       0.19000           0.00025    0.2690    0.428   89.938
#
#    duration_ms  time_signature  num_bars  num_sections  num_segments
# 0       201240               4       112             8           756
# 1       187147               4       128            10           614
# 2       233713               4        92             9          1062
# 3       257267               4       129             8          1001
# 4       177507               4        65             9           571

# %%
like_songs['song_like'] = np.ones((len(like_songs), 1), dtype=int)

like_songs.head()
# Out:
#                        id                     title  danceability  energy  \
# 0  6gBFPUFcJLzWGx4lenP6h2                goosebumps         0.841   0.728
# 1  0nrRP2bk19rLc0orkWPQk2                Wake Me Up         0.532   0.783
# 2  6RUKPb4LETWmmr3iAEQktW  Something Just Like This         0.617   0.635
# 3  7BKLCZ1jbUBVqRi2FVlTVw                    Closer         0.748   0.524
# 4  698ItKASDavgwZ3WjaWjtz                     Faded         0.468   0.627
#
#    key  loudness  mode  acousticness  instrumentalness  liveness  valence  \
# 0    7    -3.370     1        0.0847          0.000000     0.149    0.430
# 1    2    -5.697     1        0.0038          0.001200     0.161    0.643
# 2   11    -6.769     0        0.0498          0.000014     0.164    0.446
# 3    8    -5.599     1        0.4140          0.000000     0.111    0.661
# 4    6    -5.085     1        0.0281          0.000008     0.110    0.159
#
#      tempo  duration_ms  time_signature  num_bars  num_sections  num_segments  \
# 0  130.049       243837               4       130            11           958
# 1  124.080       247427               4       125            12           948
# 2  103.019       247160               4       105            11           888
# 3   95.010       244960               4        94            11           810
# 4  179.642       212107               4       154             9           687
#
#    song_like
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
dislike_songs['song_like'] = np.zeros((len(dislike_songs), 1), dtype=int)

dislike_songs.head()
# Out:
#                        id              title  danceability  energy  key  \
# 0  6Qn5zhYkTa37e91HC1D7lb  Whatever It Takes         0.672   0.655   10
# 1  1zB4vmk8tFRmM9UULNzbLB            Thunder         0.605   0.822    0
# 2  7qiZfU4dY1lWllzX7mPBI3       Shape of You         0.825   0.652    1
# 3  2tpWsVSb9UEmDRxAl1zhX1     Counting Stars         0.664   0.705    1
# 4  5qaEfEh1AtSdrdrByCP7qR             Demons         0.505   0.710    3
#
#    loudness  mode  acousticness  instrumentalness  liveness  valence    tempo  \
# 0    -5.021     0       0.03620           0.00000    0.1170    0.556  134.945
# 1    -4.833     1       0.00671           0.13400    0.1470    0.288  167.997
# 2    -3.183     0       0.58100           0.00000    0.0931    0.931   95.977
# 3    -4.972     0       0.06540           0.00000    0.1180    0.477  122.016
# 4    -3.015     1       0.19000           0.00025    0.2690    0.428   89.938
#
#    duration_ms  time_signature  num_bars  num_sections  num_segments  \
# 0       201240               4       112             8           756
# 1       187147               4       128            10           614
# 2       233713               4        92             9          1062
# 3       257267               4       129             8          1001
# 4       177507               4        65             9           571
#
#    song_like
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
like_songs.shape
# Out:
# (98, 18)

# %%
dislike_songs.shape
# Out:
# (100, 18)

# %%
songs = like_songs.append(dislike_songs,ignore_index=False)

songs.tail()
# Out:
#                         id                                              title  \
# 95  4cKLB73rkDBmJhj9xLlrMI                                          Same Team
# 96  4vUmTMuQqjdnvlZmAH61Qk  South of the Border (feat. Camila Cabello & Ca...
# 97  0afhq8XCExXpqazXczTSve                                        Galway Girl
# 98  3D5wnLaeVlCCIPzQOOAirA                                           No Roots
# 99  7MXlTgQeo3IVlMpLnZuhxc                                          It's Time
#
#     danceability  energy  key  loudness  mode  acousticness  instrumentalness  \
# 95         0.751   0.691    5    -4.855     0        0.1930          0.000001
# 96         0.857   0.621    9    -6.376     0        0.1480          0.000000
# 97         0.624   0.876    9    -3.374     1        0.0735          0.000000
# 98         0.863   0.673    4    -6.576     0        0.2580          0.002710
# 99         0.656   0.884    2    -4.748     1        0.0162          0.000000
#
#     liveness  valence    tempo  duration_ms  time_signature  num_bars  \
# 95    0.1320    0.494  124.969       211493               4       108
# 96    0.0865    0.668   97.989       204467               4        82
# 97    0.3270    0.781   99.943       170827               4        68
# 98    0.0745    0.821  115.952       237053               4       111
# 99    0.1440    0.860  105.009       240307               4       102
#
#     num_sections  num_segments  song_like
# 95            10           822          0
# 96             8           860          0
# 97             9           716          0
# 98             7           915          0
# 99            11           788          0

# %%
songs.shape
# Out:
# (198, 18)

# %%
songs = songs.drop_duplicates()

songs.shape
# Out:
# (198, 18)

# %%
songs.head()
# Out:
#                        id                     title  danceability  energy  \
# 0  6gBFPUFcJLzWGx4lenP6h2                goosebumps         0.841   0.728
# 1  0nrRP2bk19rLc0orkWPQk2                Wake Me Up         0.532   0.783
# 2  6RUKPb4LETWmmr3iAEQktW  Something Just Like This         0.617   0.635
# 3  7BKLCZ1jbUBVqRi2FVlTVw                    Closer         0.748   0.524
# 4  698ItKASDavgwZ3WjaWjtz                     Faded         0.468   0.627
#
#    key  loudness  mode  acousticness  instrumentalness  liveness  valence  \
# 0    7    -3.370     1        0.0847          0.000000     0.149    0.430
# 1    2    -5.697     1        0.0038          0.001200     0.161    0.643
# 2   11    -6.769     0        0.0498          0.000014     0.164    0.446
# 3    8    -5.599     1        0.4140          0.000000     0.111    0.661
# 4    6    -5.085     1        0.0281          0.000008     0.110    0.159
#
#      tempo  duration_ms  time_signature  num_bars  num_sections  num_segments  \
# 0  130.049       243837               4       130            11           958
# 1  124.080       247427               4       125            12           948
# 2  103.019       247160               4       105            11           888
# 3   95.010       244960               4        94            11           810
# 4  179.642       212107               4       154             9           687
#
#    song_like
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
prediction = songs.drop(['title'], axis = 1)

# %%
prediction.head()
# Out:
#                        id  danceability  energy  key  loudness  mode  \
# 0  6gBFPUFcJLzWGx4lenP6h2         0.841   0.728    7    -3.370     1
# 1  0nrRP2bk19rLc0orkWPQk2         0.532   0.783    2    -5.697     1
# 2  6RUKPb4LETWmmr3iAEQktW         0.617   0.635   11    -6.769     0
# 3  7BKLCZ1jbUBVqRi2FVlTVw         0.748   0.524    8    -5.599     1
# 4  698ItKASDavgwZ3WjaWjtz         0.468   0.627    6    -5.085     1
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0        0.0847          0.000000     0.149    0.430  130.049       243837
# 1        0.0038          0.001200     0.161    0.643  124.080       247427
# 2        0.0498          0.000014     0.164    0.446  103.019       247160
# 3        0.4140          0.000000     0.111    0.661   95.010       244960
# 4        0.0281          0.000008     0.110    0.159  179.642       212107
#
#    time_signature  num_bars  num_sections  num_segments  song_like
# 0               4       130            11           958          1
# 1               4       125            12           948          1
# 2               4       105            11           888          1
# 3               4        94            11           810          1
# 4               4       154             9           687          1

# %% [markdown]
# Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(16,16))
plt.subplot(4,4,1)
sns.distplot(songs[songs['song_like']==1]['danceability'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['danceability'], color='blue', bins=40)
plt.subplot(4,4,2)
sns.distplot(songs[songs['song_like']==1]['energy'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['energy'], color='blue', bins=40)
plt.subplot(4,4,3)
sns.distplot(songs[songs['song_like']==1]['key'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['key'], color='blue', bins=40)
plt.subplot(4,4,4)
sns.distplot(songs[songs['song_like']==1]['loudness'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['loudness'], color='blue', bins=40)
plt.legend((1,0))

# %%
plt.figure(figsize=(16,16))
plt.subplot(4,4,1)
sns.distplot(songs[songs['song_like']==1]['mode'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['mode'], color='blue', bins=40)
plt.subplot(4,4,2)
sns.distplot(songs[songs['song_like']==1]['acousticness'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['acousticness'], color='blue', bins=40)
plt.subplot(4,4,3)
sns.distplot(songs[songs['song_like']==1]['instrumentalness'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['instrumentalness'], color='blue', bins=40)
plt.subplot(4,4,4)
sns.distplot(songs[songs['song_like']==1]['liveness'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['liveness'], color='blue', bins=40)
plt.legend((1,0))

# %%
plt.figure(figsize=(16,16))
plt.subplot(4,4,1)
sns.distplot(songs[songs['song_like']==1]['valence'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['valence'], color='blue', bins=40)
plt.subplot(4,4,2)
sns.distplot(songs[songs['song_like']==1]['tempo'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['tempo'], color='blue', bins=40)
plt.subplot(4,4,3)
sns.distplot(songs[songs['song_like']==1]['duration_ms'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['duration_ms'], color='blue', bins=40)
plt.subplot(4,4,4)
sns.distplot(songs[songs['song_like']==1]['time_signature'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['time_signature'], color='blue', bins=40)
plt.legend((1,0))

# %%
plt.figure(figsize=(16,16))
plt.subplot(4,4,1)
sns.distplot(songs[songs['song_like']==1]['num_bars'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['num_bars'], color='blue', bins=40)
plt.subplot(4,4,2)
sns.distplot(songs[songs['song_like']==1]['num_sections'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['num_sections'], color='blue', bins=40)
plt.subplot(4,4,3)
sns.distplot(songs[songs['song_like']==1]['num_segments'], color='red', bins=40)
sns.distplot(songs[songs['song_like']==0]['num_segments'], color='blue', bins=40)
plt.legend((1,0))

# %% [markdown]
# Building ML Model

# %% [markdown]
# Logistic Regression

# %%
X_train = prediction.drop('song_like', axis=1)
X_test = songs.drop(['song_like','title'], axis=1)
y_train = prediction['song_like']
y_test = songs['song_like']

# %%
X_train.head()
# Out:
#                        id  danceability  energy  key  loudness  mode  \
# 0  6gBFPUFcJLzWGx4lenP6h2         0.841   0.728    7    -3.370     1
# 1  0nrRP2bk19rLc0orkWPQk2         0.532   0.783    2    -5.697     1
# 2  6RUKPb4LETWmmr3iAEQktW         0.617   0.635   11    -6.769     0
# 3  7BKLCZ1jbUBVqRi2FVlTVw         0.748   0.524    8    -5.599     1
# 4  698ItKASDavgwZ3WjaWjtz         0.468   0.627    6    -5.085     1
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0        0.0847          0.000000     0.149    0.430  130.049       243837
# 1        0.0038          0.001200     0.161    0.643  124.080       247427
# 2        0.0498          0.000014     0.164    0.446  103.019       247160
# 3        0.4140          0.000000     0.111    0.661   95.010       244960
# 4        0.0281          0.000008     0.110    0.159  179.642       212107
#
#    time_signature  num_bars  num_sections  num_segments
# 0               4       130            11           958
# 1               4       125            12           948
# 2               4       105            11           888
# 3               4        94            11           810
# 4               4       154             9           687

# %%
X_test.head()
# Out:
#                        id  danceability  energy  key  loudness  mode  \
# 0  6gBFPUFcJLzWGx4lenP6h2         0.841   0.728    7    -3.370     1
# 1  0nrRP2bk19rLc0orkWPQk2         0.532   0.783    2    -5.697     1
# 2  6RUKPb4LETWmmr3iAEQktW         0.617   0.635   11    -6.769     0
# 3  7BKLCZ1jbUBVqRi2FVlTVw         0.748   0.524    8    -5.599     1
# 4  698ItKASDavgwZ3WjaWjtz         0.468   0.627    6    -5.085     1
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0        0.0847          0.000000     0.149    0.430  130.049       243837
# 1        0.0038          0.001200     0.161    0.643  124.080       247427
# 2        0.0498          0.000014     0.164    0.446  103.019       247160
# 3        0.4140          0.000000     0.111    0.661   95.010       244960
# 4        0.0281          0.000008     0.110    0.159  179.642       212107
#
#    time_signature  num_bars  num_sections  num_segments
# 0               4       130            11           958
# 1               4       125            12           948
# 2               4       105            11           888
# 3               4        94            11           810
# 4               4       154             9           687

# %%
y_train.tail()
# Out:
# 95    0
# 96    0
# 97    0
# 98    0
# 99    0
# Name: song_like, dtype: int32

# %%
y_test.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: song_like, dtype: int32

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [81], line 1
# ----> 1 import sklearn
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.metrics import confusion_matrix, classification_report
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !which jupyter
# Out:
# /c/Users/Kaustubh/AppData/Local/Programs/Python/Python39/Scripts/jupyter

# %%
# !which jupyter-notebook
# Out:
# /c/Users/Kaustubh/AppData/Local/Programs/Python/Python39/Scripts/jupyter-notebook

# %%
# !python3 -m pip install jupyter
# !python3 -m pip install scikit-learn
# Out:
# Requirement already satisfied: jupyter in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (1.0.0)
# Requirement already satisfied: ipywidgets in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jupyter) (8.0.2)
# Requirement already satisfied: ipykernel in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jupyter) (6.16.2)
# Requirement already satisfied: qtconsole in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jupyter) (5.4.0)
# Requirement already satisfied: nbconvert in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jupyter) (7.2.4)
# Requirement already satisfied: notebook in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jupyter) (6.5.2)
# Requirement already satisfied: jupyter-console in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jupyter) (6.4.4)
# Requirement already satisfied: psutil in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipykernel->jupyter) (5.9.4)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipykernel->jupyter) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipykernel->jupyter) (7.34.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipykernel->jupyter) (6.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipykernel->jupyter) (1.6.3)
# Requirement already satisfied: nest-asyncio in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipykernel->jupyter) (1.5.6)
# Requirement already satisfied: pyzmq>=17 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipykernel->jupyter) (24.0.1)
# Requirement already satisfied: packaging in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipykernel->jupyter) (21.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipykernel->jupyter) (7.4.5)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipywidgets->jupyter) (4.0.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipywidgets->jupyter) (3.0.3)
# Requirement already satisfied: pygments in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jupyter-console->jupyter) (2.13.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jupyter-console->jupyter) (3.0.32)
# Requirement already satisfied: defusedxml in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbconvert->jupyter) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbconvert->jupyter) (2.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbconvert->jupyter) (4.11.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbconvert->jupyter) (0.7.0)
# Requirement already satisfied: nbformat>=5.1 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbconvert->jupyter) (5.7.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbconvert->jupyter) (5.0.0)
# Requirement already satisfied: tinycss2 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbconvert->jupyter) (2.0.4)
# Requirement already satisfied: jinja2>=3.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbconvert->jupyter) (4.11.2)
# Requirement already satisfied: bleach in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbconvert->jupyter) (5.0.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from notebook->jupyter) (0.17.0)
# Requirement already satisfied: prometheus-client in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from notebook->jupyter) (0.15.0)
# Requirement already satisfied: ipython-genutils in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from notebook->jupyter) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from notebook->jupyter) (1.8.0)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from notebook->jupyter) (0.4.8)
# Requirement already satisfied: argon2-cffi in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from notebook->jupyter) (21.3.0)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from qtconsole->jupyter) (2.3.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from importlib-metadata>=3.6->nbconvert->jupyter) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from importlib-metadata>=3.6->nbconvert->jupyter) (4.4.0)
# Requirement already satisfied: decorator in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.18.1)
# Requirement already satisfied: colorama in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: setuptools>=18.5 in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (47.1.0)
# Requirement already satisfied: backcall in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: entrypoints in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jupyter-core>=4.7->nbconvert->jupyter) (305)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbclassic>=0.4.7->notebook->jupyter) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbclassic>=0.4.7->notebook->jupyter) (1.23.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbformat>=5.1->nbconvert->jupyter) (4.17.0)
# Requirement already satisfied: fastjsonschema in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from nbformat>=5.1->nbconvert->jupyter) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from terminado>=0.8.3->notebook->jupyter) (2.0.9)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from argon2-cffi->notebook->jupyter) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.3.2.post1)
# Requirement already satisfied: six>=1.9.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from bleach->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from packaging->ipykernel->jupyter) (3.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (5.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (0.19.2)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (1.3.10)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (22.1.0)
# Requirement already satisfied: websocket-client in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (1.4.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (3.6.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (1.15.1)
# Requirement already satisfied: idna>=2.8 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (2.21)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_vendor\rich\console.py", line 1673, in print
#     extend(render(renderable, render_options))
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_vendor\rich\console.py", line 1305, in render
#     for render_output in iter_render:
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\utils\logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_vendor\rich\segment.py", line 249, in split_lines
#     for segment in segments:
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_vendor\rich\console.py", line 1283, in render
#     renderable = rich_cast(renderable)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_vendor\rich\protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\self_outdated_check.py", line 128, in __rich__
#     pip_cmd = f"{get_best_invocation_for_this_python()} -m pip"
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\utils\entrypoints.py", line 80, in get_best_invocation_for_this_python
#     if found_executable and os.path.samefile(found_executable, exe):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# OSError: [WinError 1920] The file cannot be accessed by the system: 'C:\\Users\\Kaustubh\\AppData\\Local\\Microsoft\\WindowsApps\\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\\python.exe'
# Call stack:
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\__main__.py", line 31, in <module>
#     sys.exit(_main())
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\cli\main.py", line 70, in main
#     return command.main(cmd_args)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\cli\base_command.py", line 216, in _main
#     self.handle_pip_version_check(options)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\cli\req_command.py", line 190, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\self_outdated_check.py", line 236, in pip_self_version_check
#     logger.warning("[present-rich] %s", upgrade_prompt)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\logging\__init__.py", line 1390, in warning
#     self._log(WARNING, msg, args, **kwargs)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\logging\__init__.py", line 1514, in _log
#     self.handle(record)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\logging\__init__.py", line 1524, in handle
#     self.callHandlers(record)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\logging\__init__.py", line 1586, in callHandlers
#     hdlr.handle(record)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\logging\__init__.py", line 894, in handle
#     self.emit(record)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.3.1', new='23.0.1'),)
# Requirement already satisfied: scikit-learn in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\kaustubh\appdata\local\packages\pythonsoftwarefoundation.python.3.7_qbz5n2kfra8p0\localcache\local-packages\python37\site-packages (from scikit-learn) (1.2.0)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_vendor\rich\console.py", line 1673, in print
#     extend(render(renderable, render_options))
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_vendor\rich\console.py", line 1305, in render
#     for render_output in iter_render:
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\utils\logging.py", line 134, in __rich_console__
#     for line in lines:
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_vendor\rich\segment.py", line 249, in split_lines
#     for segment in segments:
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_vendor\rich\console.py", line 1283, in render
#     renderable = rich_cast(renderable)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_vendor\rich\protocol.py", line 36, in rich_cast
#     renderable = cast_method()
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\self_outdated_check.py", line 128, in __rich__
#     pip_cmd = f"{get_best_invocation_for_this_python()} -m pip"
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\utils\entrypoints.py", line 80, in get_best_invocation_for_this_python
#     if found_executable and os.path.samefile(found_executable, exe):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\genericpath.py", line 101, in samefile
#     s2 = os.stat(f2)
# OSError: [WinError 1920] The file cannot be accessed by the system: 'C:\\Users\\Kaustubh\\AppData\\Local\\Microsoft\\WindowsApps\\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\\python.exe'
# Call stack:
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\__main__.py", line 31, in <module>
#     sys.exit(_main())
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\cli\main.py", line 70, in main
#     return command.main(cmd_args)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\cli\base_command.py", line 216, in _main
#     self.handle_pip_version_check(options)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\cli\req_command.py", line 190, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\self_outdated_check.py", line 236, in pip_self_version_check
#     logger.warning("[present-rich] %s", upgrade_prompt)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\logging\__init__.py", line 1390, in warning
#     self._log(WARNING, msg, args, **kwargs)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\logging\__init__.py", line 1514, in _log
#     self.handle(record)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\logging\__init__.py", line 1524, in handle
#     self.callHandlers(record)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\logging\__init__.py", line 1586, in callHandlers
#     hdlr.handle(record)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\logging\__init__.py", line 894, in handle
#     self.emit(record)
#   File "C:\Users\Kaustubh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: '[present-rich] %s'
# Arguments: (UpgradePrompt(old='22.3.1', new='23.0.1'),)
